# %%
from pandas import DataFrame
import json
import csv

# %%
file_path_users="C:/Users/ANKIT/Downloads/cqadupstack/cqadupstack/android/android/android_users.json"

# %%
file_path_questions="C:/Users/ANKIT/Downloads/cqadupstack/cqadupstack/android/android/android_questions.json"

# %%
file_path_answers="C:/Users/ANKIT/Downloads/cqadupstack/cqadupstack/android/android/android_answers.json"

# %%
with open(file_path_users) as f:
    data_users = json.load(f)

# %%
with open(file_path_questions) as f:
    data_questions = json.load(f)

# %%
with open(file_path_answers) as f:
    data_answers = json.load(f)

# %%
data_users=json.dumps(data_users)
data_users=json.loads(data_users)

# %%
data_questions=json.dumps(data_questions)
data_questions=json.loads(data_questions)

# %%
data_answers=json.dumps(data_answers)
data_answers=json.loads(data_answers)

# %%
df_users=DataFrame(data_users)

# %%
df_questions=DataFrame(data_questions)

# %%
df_answers=DataFrame(data_answers)

# %%
df_users
# Out:
#                                                                 1  \
# age                                                            37
# answers                                                        []
# badges          [Autobiographer, Supporter, Editor, Quorum, In...
# date_joined                               2010-09-13T18:54:55.607
# downvotes                                                       0
# lastaccessdate                            2014-08-14T18:00:29.560
# questions                                                      []
# rep                                                           101
# upvotes                                                         2
# views                                                        2691
#
#                                                                10  \
# age                                                            28
# answers         [12010, 6819, 6817, 10704, 833, 1721, 1680, 22...
# badges          [Autobiographer, Teacher, Student, Editor, Sel...
# date_joined                               2010-09-13T19:14:52.997
# downvotes                                                      30
# lastaccessdate                            2014-09-12T13:02:16.733
# questions       [830, 2468, 12975, 4335, 8702, 2835, 1184, 192...
# rep                                                         18666
# upvotes                                                      1477
# views                                                        2002
#
#                                                               100  \
# age                                                            30
# answers                               [147, 141, 1165, 156, 1205]
# badges          [Autobiographer, Teacher, Editor, Supporter, B...
# date_joined                               2010-09-13T20:16:03.183
# downvotes                                                       0
# lastaccessdate                            2014-05-23T14:06:30.803
# questions                                                  [1291]
# rep                                                           261
# upvotes                                                        18
# views                                                          39
#
#                                   10000                    10001  \
# age                                  37                       26
# answers                              []                       []
# badges                 [Autobiographer]         [Autobiographer]
# date_joined     2011-11-27T19:12:57.247  2011-11-27T20:30:35.113
# downvotes                             0                        0
# lastaccessdate  2014-01-06T09:00:08.673  2014-07-30T00:01:50.103
# questions                            []                       []
# rep                                 101                        1
# upvotes                               0                        0
# views                                 0                        3
#
#                                   10002                    10003  \
# age                                  48                      NaN
# answers                              []                       []
# badges                        [Student]                       []
# date_joined     2011-11-27T21:49:48.327  2011-11-28T00:08:39.493
# downvotes                             0                        0
# lastaccessdate  2011-12-05T13:06:48.220  2011-11-28T00:08:39.493
# questions                            []                       []
# rep                                   1                        1
# upvotes                               0                        0
# views                                 1                        0
#
#                                   10004                    10007  \
# age                                 NaN                       35
# answers                              []                       []
# badges                        [Student]                       []
# date_joined     2011-11-28T02:22:44.323  2011-11-28T04:02:07.560
# downvotes                             0                        0
# lastaccessdate  2011-11-28T09:38:22.763  2011-12-26T04:05:11.067
# questions                       [16083]                       []
# rep                                  21                      101
# upvotes                               0                        0
# views                                 0                        0
#
#                                   10008             ...               \
# age                                  31             ...
# answers                              []             ...
# badges                 [Autobiographer]             ...
# date_joined     2011-11-28T05:11:31.947             ...
# downvotes                             0             ...
# lastaccessdate  2013-02-28T09:04:24.020             ...
# questions                            []             ...
# rep                                 101             ...
# upvotes                               0             ...
# views                                 0             ...
#
#                                    9987  \
# age                                 NaN
# answers                              []
# badges                        [Student]
# date_joined     2011-11-27T11:02:48.527
# downvotes                             0
# lastaccessdate  2011-11-27T13:25:24.457
# questions                       [16055]
# rep                                  21
# upvotes                               0
# views                                 2
#
#                                                              9989  \
# age                                                           NaN
# answers                                                   [24989]
# badges          [Supporter, Teacher, Editor, Revival, Discipli...
# date_joined                               2011-11-27T12:47:33.817
# downvotes                                                       0
# lastaccessdate                            2014-05-03T11:15:51.403
# questions                                                      []
# rep                                                           251
# upvotes                                                         6
# views                                                          18
#
#                                                999                     9990  \
# age                                             36                       51
# answers                                         []                       []
# badges          [Autobiographer, Scholar, Student]         [Autobiographer]
# date_joined                2010-11-06T22:58:49.817  2011-11-27T13:23:35.053
# downvotes                                        0                        0
# lastaccessdate             2010-11-08T10:59:04.260  2011-12-12T04:06:06.537
# questions                                   [2678]                       []
# rep                                              8                      101
# upvotes                                          0                        0
# views                                           16                        2
#
#                                    9992  \
# age                                 NaN
# answers                              []
# badges                        [Student]
# date_joined     2011-11-27T15:37:00.140
# downvotes                             0
# lastaccessdate  2011-11-28T18:46:28.250
# questions                       [16065]
# rep                                  21
# upvotes                               0
# views                                 0
#
#                                                              9993  \
# age                                                            42
# answers                       [55121, 55077, 57712, 39309, 55068]
# badges          [Student, Editor, Autobiographer, Supporter, S...
# date_joined                               2011-11-27T17:34:49.943
# downvotes                                                       0
# lastaccessdate                            2014-07-27T23:07:04.650
# questions       [54786, 57705, 16071, 56490, 38544, 33542, 335...
# rep                                                           320
# upvotes                                                        28
# views                                                          56
#
#                                    9995                     9996  \
# age                                  32                      NaN
# answers                              []                  [16074]
# badges                      [Supporter]                       []
# date_joined     2011-11-27T17:42:49.023  2011-11-27T17:56:52.657
# downvotes                             0                        0
# lastaccessdate  2011-12-31T03:05:00.480  2011-11-27T17:56:52.657
# questions                            []                       []
# rep                                 101                       11
# upvotes                               1                        0
# views                                 4                        2
#
#                                                          9998  \
# age                                                       NaN
# answers                                                    []
# badges          [Student, Popular Question, Notable Question]
# date_joined                           2011-11-27T18:56:39.200
# downvotes                                                   0
# lastaccessdate                        2011-11-27T18:56:39.200
# questions                                             [16078]
# rep                                                        11
# upvotes                                                     0
# views                                                       2
#
#                                        9999
# age                                      31
# answers                                  []
# badges          [Autobiographer, Supporter]
# date_joined         2011-11-27T19:06:05.227
# downvotes                                 0
# lastaccessdate      2014-03-15T17:47:40.043
# questions                                []
# rep                                     101
# upvotes                                   7
# views                                     0
#
# [10 rows x 51407 columns]

# %%
df_users.loc['badges','1']
# Out:
# ['Autobiographer', 'Supporter', 'Editor', 'Quorum', 'Informed']

# %%
#removing unwanted collumns
df_answers=df_answers.drop(['creationdate'],axis=1)

# %%
df_users.head()
# Out:
#                                                  answers downvotes  \
# 1                                                     []         0
# 10     [12010, 6819, 6817, 10704, 833, 1721, 1680, 22...        30
# 100                          [147, 141, 1165, 156, 1205]         0
# 10000                                                 []         0
# 10001                                                 []         0
#
#                                                questions    rep upvotes views
# 1                                                     []    101       2  2691
# 10     [830, 2468, 12975, 4335, 8702, 2835, 1184, 192...  18666    1477  2002
# 100                                               [1291]    261      18    39
# 10000                                                 []    101       0     0
# 10001                                                 []      1       0     3

# %%
df_questions.head()
# Out:
#       acceptedanswer                answers  \
# 1                 13            [29185, 13]
# 10003          10004                [10004]
# 10009          False  [16490, 16492, 10012]
# 1001           False                 [1002]
# 10011          10024  [10027, 10024, 41162]
#
#                                                     body  \
# 1      <p>This is a common question by those who have...
# 10003  <p>I am trying to Lock Screen Widget, But I am...
# 10009  <p>I have looked through the site, and it does...
# 1001   <p>On the Droid X I'm able to create contact g...
# 10011  <p>I have recently installed JuiceDefender (JD...
#
#                                   comments             creationdate dups  \
# 1                                       []  2010-09-13T19:16:26.763   []
# 10003                                   []  2011-06-02T22:22:10.663   []
# 10009  [12113, 12114, 12129, 12167, 19259]  2011-06-03T03:59:45.887   []
# 1001                                    []  2010-07-22T18:33:51.723   []
# 10011                                   []  2011-06-03T06:54:16.630   []
#
#       favoritecount related score  \
# 1               119      []   172
# 10003             0      []     2
# 10009             1  [4614]     6
# 1001              0      []     1
# 10011             0      []     3
#
#                                                     tags  \
# 1                                        [rooting, root]
# 10003  [nexus-one, uninstallation, device-administrator]
# 10009        [system-freeze, samsung-galaxy-gio, setcpu]
# 1001                              [contacts, 2.1-eclair]
# 10011                   [samsung-galaxy-s, battery-life]
#
#                                                    title userid viewcount
# 1      I've rooted my phone.  Now what?  What do I ga...     10    207478
# 10003  How can I uninstall Lock Screen Widget from my...   2220       513
# 10009  Phone randomly black screens, forced to remove...   2810      2826
# 1001                    Manage Contact Groups on Droid X  False       621
# 10011  What is my phone doing at 1 o'clock in the mor...    526       240

# %%
df_answers.head()
# Out:
#                                                     body  \
# 10     <p>The clearest answer I've seen is here: <a h...
# 100    <p>Phone service carriers will sometimes updat...
# 1000   <p>Can you check with the GPS turned off for a...
# 10000  <p>Assuming your computer doesn't have a Wi-Fi...
# 10001  <p>As Ryan said, you can export the contacts t...
#
#                     comments parentid score userid
# 10                      [72]        2     6     29
# 100                       []       70     0     34
# 1000              [726, 727]      999     3  False
# 10000                     []     3134     0   5641
# 10001  [12098, 12134, 12135]     9993     1   5642

# %%
 df_users.ix[0]
# Out:
# C:\Users\ANKIT\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# answers        []
# downvotes       0
# questions      []
# rep           101
# upvotes         2
# views        2691
# Name: 1, dtype: object

# %%
class Users:
